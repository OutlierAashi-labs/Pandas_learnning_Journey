# %% [markdown]
# # **Series**

# %% [markdown]
# ### Basic Series

# %%
import numpy as np
import pandas as pd

# %%
# String 
country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: str

# %%
# Integer 
runs = [13,26,39,57,90]
run_ser = pd.Series(runs)
run_ser
# Out:
# 0    13
# 1    26
# 2    39
# 3    57
# 4    90
# dtype: int64

# %%
# Custom Index
marks = [50,67,76,80]
subjects = ['maths','chemistry','physics','Hindi']

pd.Series(marks,index=subjects)
# Out:
# maths        50
# chemistry    67
# physics      76
# Hindi        80
# dtype: int64

# %%
# Setting the name of series

pd.Series(marks,index=subjects,name='Aashi ke marks')
# Out:
# maths        50
# chemistry    67
# physics      76
# Hindi        80
# Name: Aashi ke marks, dtype: int64

# %% [markdown]
# ### Series from dictionary

# %%
marks = {
    'maths' : 467,
    'english': 387,
    'science': 297,
    'hindi' : 110
}


marks_series = pd.Series (marks , name = 'HmHogyeKamyab')
marks_series
# Out:
# maths      467
# english    387
# science    297
# hindi      110
# Name: HmHogyeKamyab, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size

marks_series.size
# Out:
# 4

# %%
# dtype

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'HmHogyeKamyab'

# %%
# is_unique

# marks_series.is_unique

pd.Series([1,1,2,3,4]).is_unique
# Out:
# False

# %%
# index

# marks_series.index

run_ser.index

# type(run_ser.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values

marks_series.values

type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
# pd.read_csv('subs.csv')

# type(pd.read_csv('subs.csv')) # Type: Dataframe

# pd.read_csv('subs.csv', squeeze=True)  # remove in newer version , so dont use it for changing dataframe to series


Subs = pd.read_csv('subs.csv')['Subscribers gained']
Subs
# type( pd.read_csv('subs.csv')['Subscribers gained'])
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('kohli_ipl.csv',index_col='match_no')['runs']
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
Movies = pd.read_csv('bollywood.csv',index_col='movie')['lead']
Movies
# type(Movies)

# %% [markdown]
# ### Series methods

# %% [markdown]
# #### head and tail

# %%
Subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %% [markdown]
# #### sample

# %%
Movies.sample(4)
# Out:
# movie
# Love Breakups Zindagi          Zayed Khan
# Banaras (2006 film)      Urmila Matondkar
# Swami (2007 film)          Manoj Bajpayee
# Tumbbad                        Sohum Shah
# Name: lead, dtype: str

# %% [markdown]
# #### values_counts

# %%
Movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# #### sort_values

# %%
vk.sort_values() # default ascending order
vk.sort_values(ascending=False) # descending order
vk.sort_values(ascending=False).head(10) # top 10 scores
vk.sort_values(ascending=False).head(1).values[0] # highest score 
# When we apply .values[0] it will give us the value of highest score instead of series
# Method chaining is used for applying multiple methods in a single line of code. It allows us to perform a series of operations on a DataFrame or Series without the need for intermediate variables. This can make the code more concise and easier to read.
# vk.sort_values(inplace=True)
# inplace=True means that the original series will be modified and sorted in place, rather than creating a new sorted series. This can save memory and improve performance when working with large datasets.
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# #### sort_index
